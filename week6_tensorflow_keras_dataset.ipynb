# %% [markdown]
# <a href="https://colab.research.google.com/github/Ali-Alameer/Deep-Learning/blob/main/week6_tensorflowhub_with_your_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transfer learning with TensorFlow

# %% [markdown]
# tf.keras.applications
#
# This workshop demonstrates how to:
#
# 1. Use models from TensorFlow with `tf.keras.applications`.
# 1. Use an image classification model from TensorFlow.
# 1. Do simple transfer learning to fine-tune a model for your own image classes.

# %% [markdown]
# ## Setup

# %%
import numpy as np
import time

import PIL.Image as Image
import matplotlib.pylab as plt

import tensorflow as tf
import tensorflow_hub as hub

import datetime

# %load_ext tensorboard

# %% [markdown]
# ## An ImageNet classifier
#
# You'll start by using a classifier model pre-trained on the [ImageNet](https://en.wikipedia.org/wiki/ImageNet) benchmark dataset—no initial training required!

# %% [markdown]
# ### Download the classifier
#
# Read Docs
#
# [MobileNetV3Large](https://www.tensorflow.org/api_docs/python/tf/keras/applications/MobileNetV3Large)
# MobileNetV3Large: A lightweight and efficient model suitable for mobile and embedded devices.
# <br>
# [InceptionV3](https://www.tensorflow.org/api_docs/python/tf/keras/applications/InceptionV3)
# InceptionV3: A deep neural network architecture known for high accuracy on image classification tasks.

# %%
IMAGE_SHAPE = (224, 224)

print("Choose a model:")
print("1. MobileNetV3")
print("2. InceptionV3")

choice = input("Enter your choice (1/2): ")

if choice == "1":
    base_model = tf.keras.applications.MobileNetV3Large(
        weights='imagenet',
        include_top=False,
        input_shape=IMAGE_SHAPE + (3,)
    )
elif choice == "2":
    base_model = tf.keras.applications.InceptionV3(
        weights='imagenet',
        include_top=False,
        input_shape=IMAGE_SHAPE + (3,)
    )
else:
    print("Invalid choice. Defaulting to MobileNetV3.")
    base_model = tf.keras.applications.MobileNetV3Large(
        weights='imagenet',
        include_top=False,
        input_shape=IMAGE_SHAPE + (3,)
    )

classifier = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(1000, activation='softmax')
])

base_model.trainable = False

print(f"Using {base_model.name} as the base model with input shape {IMAGE_SHAPE + (3,)}")
# Out:
# Choose a model:
# 1. MobileNetV3
# 2. InceptionV3
# Enter your choice (1/2): 2
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87910968/87910968 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step
# Using inception_v3 as the base model with input shape (224, 224, 3)

# %% [markdown]
# ### Run it on a single image

# %% [markdown]
# Download a single image to try the model on:

# %%
grace_hopper = tf.keras.utils.get_file('image.jpg','https://storage.googleapis.com/download.tensorflow.org/example_images/grace_hopper.jpg')
grace_hopper = Image.open(grace_hopper).resize(IMAGE_SHAPE)
grace_hopper
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/grace_hopper.jpg
# 61306/61306 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# <PIL.Image.Image image mode=RGB size=224x224>

# %%
grace_hopper = np.array(grace_hopper)/255.0
grace_hopper.shape
# Out:
# (224, 224, 3)

# %% [markdown]
# Add a batch dimension (with `np.newaxis`) and pass the image to the model:

# %%
result = classifier.predict(grace_hopper[np.newaxis, ...])
result.shape
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step
# (1, 1000)

# %% [markdown]
# The result is a 1001-element vector of logits, rating the probability of each class for the image.
#
# The top class ID can be found with `tf.math.argmax`:

# %%
predicted_class = tf.math.argmax(result[0], axis=-1)
predicted_class
# Out:
# <tf.Tensor: shape=(), dtype=int64, numpy=836>

# %% [markdown]
# ### Decode the predictions
#
# Take the `predicted_class` ID (such as `653`) and fetch the ImageNet dataset labels to decode the predictions:

# %%
labels_path = tf.keras.utils.get_file('ImageNetLabels.txt','https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt')
imagenet_labels = np.array(open(labels_path).read().splitlines())
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/data/ImageNetLabels.txt
# 10484/10484 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
plt.imshow(grace_hopper)
plt.axis('off')
predicted_class_name = imagenet_labels[predicted_class]
_ = plt.title("Prediction: " + predicted_class_name.title())

# %% [markdown]
# ## Simple transfer learning

# %% [markdown]
# But what if you want to create a custom classifier using your own dataset that has classes that aren't included in the original ImageNet dataset (that the pre-trained model was trained on)?
#
# To do that, you can:
#
# 1. Select a pre-trained model from TensorFlow and
# 2. Retrain the top (last) layer to recognize the classes from your custom dataset.

# %% [markdown]
# ### Dataset
#
# In this example, you will use the unversity of Salford buildings dataset:

# %%
import pathlib

print("🔽 Downloading dataset...")
dataset_url = "https://salford.figshare.com/ndownloader/files/36524085"
data_dir = tf.keras.utils.get_file('dataset', origin=dataset_url, untar=True, cache_dir='/content')
data_dir = pathlib.Path(data_dir)

# ✅ Auto-fix double folder structure
if (data_dir / "dataset" / "dataset").exists():
    data_dir = data_dir / "dataset" / "dataset"
elif (data_dir / "dataset").exists():
    data_dir = data_dir / "dataset"

print("✅ Using dataset directory:", data_dir)
# Out:
# 🔽 Downloading dataset...
# Downloading data from https://salford.figshare.com/ndownloader/files/36524085
# 3037144022/3037144022 ━━━━━━━━━━━━━━━━━━━━ 38s 0us/step
# ✅ Using dataset directory: /content/datasets/dataset/dataset

# %% [markdown]
# If you have your dataset collected by yourself, upload to your google drive and use the below code:

# %%
#from google.colab import drive
#drive.mount('/content/drive')
#import pathlib
#data_dir = "/content/drive/MyDrive/dataset/"
#data_dir = pathlib.Path(data_dir)

# %% [markdown]
# First, load this data into the model using the image data off disk with `tf.keras.utils.image_dataset_from_directory`, which will generate a `tf.data.Dataset`:

# %%
BATCH_SIZE = 32
IMG_SIZE = (224, 224)

# %%
train_dataset = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=IMG_SIZE,
  batch_size=BATCH_SIZE)
# Out:
# Found 751 files belonging to 10 classes.
# Using 601 files for training.

# %%
validation_dataset = tf.keras.utils.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=IMG_SIZE,
  batch_size=BATCH_SIZE)
# Out:
# Found 751 files belonging to 10 classes.
# Using 150 files for validation.

# %%
train_ds = train_dataset
val_ds = validation_dataset

# %% [markdown]
# See classes of the dataset:

# %%
class_names = np.array(train_ds.class_names)
print(class_names)
# Out:
# ['Chapman' 'Cockcroft' 'Library' 'Maxwell' 'Media City Campus'
#  'New Adelphi' 'New Science' 'Newton' 'Sports Center' 'University House']

# %% [markdown]
# Note: You could also include the `tf.keras.layers.Rescaling` layer inside the model. Refer to the [Working with preprocessing layers](https://www.tensorflow.org/guide/keras/preprocessing_layers) guide for a discussion of the tradeoffs.

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y)) # Where x—images, y—labels.
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y)) # Where x—images, y—labels.

# %%
AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 224, 224, 3)
# (32,)

# %% [markdown]
# ### Run the classifier on a batch of images

# %% [markdown]
# Now, run the classifier on an image batch:

# %%
result_batch = classifier.predict(train_ds)
# Out:
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 58s 2s/step

# %%
predicted_class_names = imagenet_labels[tf.math.argmax(result_batch, axis=-1)]
predicted_class_names
# Out:
# array(['hay', 'affenpinscher', 'stupa', 'hay', 'magnetic compass',
#        'garbage truck', 'Gila monster', 'pickup', 'hay', 'hay', 'eel',
#        'potpie', 'sundial', 'bullfrog', 'bullfrog', 'hay', 'ocarina',
#        'bullfrog', 'Great Pyrenees', 'stupa', 'stupa', 'obelisk', 'hay',
#        'rotisserie', 'tree frog', 'hay', 'hay', 'trolleybus', 'sundial',
#        'hay', 'hay', 'beach wagon', 'hay', 'hay', 'bullfrog', 'switch',
#        'golf ball', 'rhinoceros beetle', 'rhinoceros beetle', 'tile roof',
#        'switch', 'hay', 'Shih-Tzu', 'trolleybus', 'hay', 'mixing bowl',
#        'trolleybus', 'monastery', 'hay', 'rain barrel', 'mailbox', 'hay',
#        'bullfrog', 'rhinoceros beetle', 'hay', 'hay', 'hay', 'mailbox',
#        'magnetic compass', 'hay', 'monastery', 'switch',
#        'rhinoceros beetle', 'magnetic compass', 'sundial', 'hay',
#        'radio telescope', 'shoe shop', 'obelisk', 'hay', 'hay', 'ocarina',
#        'hay', 'hay', 'hay', 'hay', 'hay', 'microphone', 'switch', 'dome',
#        'stretcher', 'trolleybus', 'hay', 'hay', 'bullfrog', 'beach wagon',
#        'chow', 'armadillo', 'trolleybus', 'hay', 'hay', 'strawberry',
#        'shoe shop', 'hay', 'trolleybus', 'switch', 'paintbrush', 'hay',
#        'hay', 'hay', 'hay', 'hay', 'golf ball', 'obelisk', 'switch',
#        'bullfrog', 'hay', 'mixing bowl', 'hay',
#        'Staffordshire bullterrier', 'strawberry', 'shoe shop', 'stupa',
#        'scoreboard', 'switch', 'obelisk', 'hay', 'yurt', 'hay',
#        'strawberry', 'hay', 'candle', 'shoe shop', 'hay', 'barometer',
#        'beach wagon', 'hay', 'sundial', 'hay', 'pole', 'stupa', 'hay',
#        'hay', 'hay', 'obelisk', 'yurt', 'rain barrel', 'trolleybus',
#        'trolleybus', 'gondola', 'bullfrog', 'tree frog', 'stupa',
#        'beach wagon', 'trolleybus', 'stupa', 'hay', 'tractor', 'switch',
#        'switch', 'parachute', 'hay', 'hay', 'buckeye', 'magnetic compass',
#        'collie', 'magnetic compass', 'switch', 'bullfrog', 'switch',
#        'hay', 'trolleybus', 'hay', 'bikini', 'tractor', 'strawberry',
#        'paddle', 'hay', 'bullfrog', 'hay', 'rhinoceros beetle', 'switch',
#        'beach wagon', 'stupa', 'hay', 'trolleybus', 'hay', 'hay',
#        'monastery', 'sundial', 'hay', 'hay', 'white stork', 'hay', 'hay',
#        'hay', 'trolleybus', 'hay', 'hay', 'hay', 'water snake', 'switch',
#        'hay', 'schipperke', 'hay', 'golf ball', 'hay', 'schipperke',
#        'submarine', 'sundial', 'obelisk', 'shoe shop', 'beach wagon',
#        'hay', 'greenhouse', 'bullfrog', 'switch', 'sundial', 'yurt',
#        'beach wagon', 'giant panda', 'hay', 'tractor', 'switch', 'hay',
#        'yurt', 'hot pot', 'Shih-Tzu', 'switch', 'scoreboard',
#        'greenhouse', 'miniature schnauzer', 'barometer', 'hay', 'hay',
#        'hay', 'hay', 'stupa', 'potpie', 'tractor', 'hay', 'hay',
#        'mixing bowl', 'hay', 'hay', 'stupa', 'hay', 'switch', 'shoe shop',
#        'hay', 'trolleybus', 'hay', 'hay', 'hay', 'hay', 'tree frog',
#        'switch', 'beach wagon', 'tractor', 'hay', 'hay', 'hay', 'paddle',
#        'hay', 'lesser panda', 'beach wagon', 'hay', 'trolleybus', 'hay',
#        'tractor', 'eel', 'switch', 'hay', 'hay', 'potpie', 'tree frog',
#        'yurt', 'beach wagon', 'sundial', 'hay', 'hay', 'stupa',
#        'rhinoceros beetle', 'hay', 'bullfrog', 'Shih-Tzu',
#        'sewing machine', 'obelisk', 'hay', 'obelisk', 'monastery',
#        'trolleybus', 'strawberry', 'sundial', 'tile roof',
#        'radio telescope', 'hay', 'bullfrog', 'hard disc', 'Gila monster',
#        'hay', 'hay', 'hay', 'giant panda', 'beach wagon', 'hay', 'kite',
#        'trolleybus', 'Gila monster', 'switch', 'beach wagon', 'mantis',
#        'switch', 'hay', 'hay', 'hay', 'rhinoceros beetle', 'hay',
#        'switch', 'obelisk', 'shoe shop', 'yurt', 'beach wagon', 'hay',
#        'white stork', 'hay', 'hay', 'hay', 'dome', 'hay', 'hay',
#        'schipperke', 'hay', 'hay', 'eel', 'scoreboard', 'yurt',
#        'beach wagon', 'bullfrog', 'switch', 'beach wagon', 'hay',
#        'Gila monster', 'water snake', 'hay', 'shoe shop', 'hay',
#        'scoreboard', 'hay', 'beach wagon', 'hay', 'monastery', 'obelisk',
#        'tractor', 'stupa', 'Gila monster', 'hay', 'beach wagon',
#        'obelisk', 'hay', 'radio telescope', 'trolleybus', 'hay',
#        'bullfrog', 'bullfrog', 'shoe shop', 'bullfrog', 'beach wagon',
#        'eel', 'stupa', 'hay', 'switch', 'hay', 'white stork',
#        'trolleybus', 'switch', 'hay', 'bullfrog', 'hay', 'Gila monster',
#        'lynx', 'hay', 'beach wagon', 'hay', 'eel', 'sundial', 'monitor',
#        'beach wagon', 'trolleybus', 'hay', 'hay', 'shoe shop', 'switch',
#        'beach wagon', 'stupa', 'hay', 'radio telescope', 'switch', 'hay',
#        'hay', 'hay', 'sundial', 'hay', 'typewriter keyboard', 'mailbox',
#        'hay', 'sundial', 'hay', 'hay', 'rhinoceros beetle', 'hay',
#        'shoe shop', 'bullfrog', 'beach wagon', 'chow', 'sundial',
#        'mixing bowl', 'bullfrog', 'switch', 'trolleybus', 'bullfrog',
#        'yurt', 'beach wagon', 'magnetic compass', 'stupa', 'hay', 'hay',
#        'shoe shop', 'hot pot', 'sundial', 'beach wagon', 'white stork',
#        'jacamar', 'hay', 'barometer', 'bullfrog', 'hay', 'schipperke',
#        'tractor', 'rhinoceros beetle', 'face powder', 'hay', 'switch',
#        'sundial', 'Gila monster', 'stupa', 'hay', 'hay', 'switch',
#        'bassinet', 'switch', 'switch', 'hay', 'hay', 'candle',
#        'mixing bowl', 'hay', 'thresher', 'hay', 'beach wagon', 'hay',
#        'hay', 'shoe shop', 'trolleybus', 'sundial', 'stupa', 'switch',
#        'beach wagon', 'hard disc', 'stupa', 'hay', 'switch', 'hay', 'hay',
#        'hay', 'hay', 'hay', 'eel', 'beach wagon', 'radio telescope',
#        'hay', 'hay', 'hay', 'hay', 'tractor', 'Staffordshire bullterrier',
#        'hay', 'hay', 'hay', 'beach wagon', 'scoreboard', 'trolleybus',
#        'trolleybus', 'Gila monster', 'tractor', 'lynx', 'hay', 'hay',
#        'hay', 'white stork', 'hay', 'golf ball', 'scoreboard', 'switch',
#        'beach wagon', 'beach wagon', 'beach wagon', 'hay', 'beach wagon',
#        'flute', 'hay', 'hay', 'hay', 'bullfrog', 'hay', 'monastery',
#        'switch', 'mixing bowl', 'obelisk', 'sundial', 'stretcher',
#        'strawberry', 'Shih-Tzu', 'axolotl', 'hay', 'beach wagon', 'stupa',
#        'sundial', 'trolleybus', 'hay', 'hay', 'mixing bowl', 'bullfrog',
#        'tree frog', 'hay', 'switch', 'beach wagon', 'hay', 'Gila monster',
#        'chow', 'yurt', 'flute', 'bullfrog', 'trolleybus', 'barometer',
#        'paddle', 'rhinoceros beetle', 'hay', 'switch', 'hay',
#        'miniature schnauzer', 'bullfrog', 'beach wagon', 'hay', 'pickup',
#        'switch', 'beach wagon', 'yurt', 'minivan', 'trolleybus', 'stupa',
#        'hay', 'sundial', 'beach wagon', 'trolleybus', 'hay', 'hay',
#        'bikini', 'hay', 'switch', 'hay', 'hay', 'white stork', 'hay',
#        'hay', 'magnetic compass', 'rhinoceros beetle', 'hay',
#        'beach wagon', 'schipperke', 'hay', 'greenhouse', 'beach wagon',
#        'hay', 'hoopskirt', 'hay', 'rhinoceros beetle', 'schipperke',
#        'hay', 'hay', 'beach wagon', 'hay', 'stupa', 'hay', 'beach wagon',
#        'shoe shop', 'hay', 'chow', 'hay', 'hay', 'switch', 'hay',
#        'bassinet', 'sundial', 'strawberry', 'hay', 'hay', 'eel',
#        'fountain', 'hay', 'trolleybus'], dtype='<U30')

# %% [markdown]
# Check how these predictions line up with the images:

# %%
plt.figure(figsize=(10,9))
plt.subplots_adjust(hspace=0.5)
for n in range(30):
  plt.subplot(6,5,n+1)
  plt.imshow(image_batch[n])
  plt.title(predicted_class_names[n])
  plt.axis('off')
_ = plt.suptitle("ImageNet predictions")

# %% [markdown]
# The results are far from perfect, but reasonable considering that these are not

# %% [markdown]
# ### Download the Headless Model
#
# TensorFlow Hub also distributes models without the top classification layer. These can be used to easily perform transfer learning.
#
# [TensorFlow LOAD and SAVE Model](https://www.tensorflow.org/tutorials/keras/save_and_load)

# %% [markdown]
# Imports

# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pathlib
import datetime

# %% [markdown]
# Dataset Setup

# %%
print("🔽 Downloading dataset...")
dataset_url = "https://salford.figshare.com/ndownloader/files/36524085"
data_dir = tf.keras.utils.get_file('dataset', origin=dataset_url, untar=True, cache_dir='/content')
data_dir = pathlib.Path(data_dir)

# ✅ Auto-fix double folder structure
if (data_dir / "dataset" / "dataset").exists():
    data_dir = data_dir / "dataset" / "dataset"
elif (data_dir / "dataset").exists():
    data_dir = data_dir / "dataset"

print("✅ Using dataset directory:", data_dir)
# Out:
# 🔽 Downloading dataset...
# ✅ Using dataset directory: /content/datasets/dataset/dataset

# %% [markdown]
# Dataset Loading

# %%
BATCH_SIZE = 32
IMG_SIZE = (224, 224)

train_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="training",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_dataset = tf.keras.utils.image_dataset_from_directory(
    data_dir,
    validation_split=0.2,
    subset="validation",
    seed=123,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

# ✅ Get class names
class_names = np.array(train_dataset.class_names)
print("Detected classes:", class_names)
print(f"Total number of classes: {len(class_names)}")
# Out:
# Found 751 files belonging to 10 classes.
# Using 601 files for training.
# Found 751 files belonging to 10 classes.
# Using 150 files for validation.
# Detected classes: ['Chapman' 'Cockcroft' 'Library' 'Maxwell' 'Media City Campus'
#  'New Adelphi' 'New Science' 'Newton' 'Sports Center' 'University House']
# Total number of classes: 10

# %% [markdown]
# Pre-Preprocessing

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)
train_ds = train_dataset.map(lambda x, y: (normalization_layer(x), y))
val_ds = val_dataset.map(lambda x, y: (normalization_layer(x), y))

AUTOTUNE = tf.data.AUTOTUNE
train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# Quick label check
for _, labels in train_ds.take(1):
    print("Unique labels in batch:", np.unique(labels.numpy()))
# Out:
# Unique labels in batch: [0 1 2 3 5 6 7 8 9]

# %% [markdown]
# Model Selection

# %%
print("\nChoose a base model:")
print("1️⃣  MobileNetV2")
print("2️⃣  InceptionV3")

choice = input("Enter your choice (1 or 2): ")

IMAGE_SHAPE = IMG_SIZE

if choice == "1":
    base_model = tf.keras.applications.MobileNetV2(
        weights='imagenet', include_top=False, input_shape=IMAGE_SHAPE + (3,)
    )
elif choice == "2":
    base_model = tf.keras.applications.InceptionV3(
        weights='imagenet', include_top=False, input_shape=IMAGE_SHAPE + (3,)
    )
else:
    print("⚠️ Invalid choice. Defaulting to MobileNetV2.")
    base_model = tf.keras.applications.MobileNetV2(
        weights='imagenet', include_top=False, input_shape=IMAGE_SHAPE + (3,)
    )

base_model.trainable = False
print(f"✅ Using {base_model.name} as the base model")
# Out:
# Choose a base model:
# 1️⃣  MobileNetV2
# 2️⃣  InceptionV3
# Enter your choice (1 or 2): 2
# ✅ Using inception_v3 as the base model

# %% [markdown]
# Model Architecture

# %%
num_classes = len(class_names)

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.3),
    tf.keras.layers.Dense(num_classes, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ inception_v3 (Functional)       │ (None, 5, 5, 2048)     │    21,802,784 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d_1      │ (None, 2048)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │       262,272 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 22,066,346 (84.18 MB)
#  Trainable params: 263,562 (1.01 MB)
#  Non-trainable params: 21,802,784 (83.17 MB)

# %% [markdown]
# Compile & Train

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=['accuracy']
)

log_dir = "logs/fit/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq=1)

EPOCHS = 10
print("\n🚀 Starting training...")
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=EPOCHS,
    callbacks=[tensorboard_callback]
)
# Out:
# 🚀 Starting training...
# Epoch 1/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 91s 4s/step - accuracy: 0.1858 - loss: 2.4676 - val_accuracy: 0.6000 - val_loss: 1.4510
# Epoch 2/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 428ms/step - accuracy: 0.5102 - loss: 1.4554 - val_accuracy: 0.6733 - val_loss: 1.0494
# Epoch 3/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 437ms/step - accuracy: 0.6739 - loss: 0.9738 - val_accuracy: 0.7267 - val_loss: 0.8815
# Epoch 4/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 409ms/step - accuracy: 0.7640 - loss: 0.7680 - val_accuracy: 0.7733 - val_loss: 0.8103
# Epoch 5/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 437ms/step - accuracy: 0.8261 - loss: 0.6366 - val_accuracy: 0.7400 - val_loss: 0.7379
# Epoch 6/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 438ms/step - accuracy: 0.8496 - loss: 0.5267 - val_accuracy: 0.7200 - val_loss: 0.7437
# Epoch 7/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 7s 393ms/step - accuracy: 0.8565 - loss: 0.4491 - val_accuracy: 0.7867 - val_loss: 0.6833
# Epoch 8/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 434ms/step - accuracy: 0.9134 - loss: 0.3756 - val_accuracy: 0.8067 - val_loss: 0.6136
# Epoch 9/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 10s 436ms/step - accuracy: 0.8981 - loss: 0.3467 - val_accuracy: 0.8200 - val_loss: 0.5444
# Epoch 10/10
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 8s 419ms/step - accuracy: 0.9277 - loss: 0.2598 - val_accuracy: 0.8333 - val_loss: 0.5233

# %% [markdown]
# Visualize Training

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(EPOCHS)

plt.figure(figsize=(10, 4))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Loss')
plt.show()

# %% [markdown]
# Save Model & Reload Saved Model

# %%
save_path = "/content/salford_buildings_model.keras"
model.save(save_path)
print(f"\n✅ Model saved at: {save_path}")

print("\n♻️ Reloading saved model...")
reloaded_model = tf.keras.models.load_model(save_path)
print("✅ Model successfully reloaded.")
# Out:
# ✅ Model saved at: /content/salford_buildings_model.keras
#
# ♻️ Reloading saved model...
# ✅ Model successfully reloaded.

# %% [markdown]
# Predictions Visualization

# %%
print("\n🔍 Making sample predictions...")
image_batch, label_batch = next(iter(val_ds))
predictions = model.predict(image_batch)
predicted_ids = tf.argmax(predictions, axis=-1)
predicted_labels = [class_names[i] for i in predicted_ids.numpy()]

plt.figure(figsize=(12, 10))
for n in range(9):
    plt.subplot(3, 3, n + 1)
    plt.imshow(image_batch[n].numpy())
    plt.title(f"Pred: {predicted_labels[n]}\nTrue: {class_names[label_batch[n]]}")
    plt.axis('off')
plt.suptitle("Model Predictions")
plt.show()
# Out:
# 🔍 Making sample predictions...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
